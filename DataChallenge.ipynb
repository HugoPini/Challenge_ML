# %% [markdown]
# # Chargement des données

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
# utilisation de pd.read_csv pour charger les fichiers dans les dataframes
data = pd.read_csv('ytrain.csv',sep=",", decimal=".",engine='python', parse_dates=['timestamp'])
df_test = pd.read_csv('ytest.csv',sep=",", decimal=".",engine='python')

# %%
data.shape
# Out:
# (31232, 274)

# %%
data.head()
# Out:
#                   timestamp S7-T1 S2-T1     S19-T1 S56-T3 S85-T3   S16-T3  \
# 0 2019-11-25 00:00:00+00:00  Down  Down  Available   Down   Down  Offline
# 1 2019-11-25 00:15:00+00:00  Down  Down  Available   Down   Down  Offline
# 2 2019-11-25 00:30:00+00:00  Down  Down  Available   Down   Down  Offline
# 3 2019-11-25 00:45:00+00:00  Down  Down  Available   Down   Down  Offline
# 4 2019-11-25 01:00:00+00:00  Down  Down  Available   Down   Down  Offline
#
#     S16-T1   S94-T3     S28-T1  ... S47-T2   S65-T2   S32-T2     S21-T2  \
# 0  Offline  Offline  Available  ...   Down  Offline  Offline  Available
# 1  Offline  Offline  Available  ...   Down  Offline  Offline  Available
# 2  Offline  Offline  Available  ...   Down  Offline  Offline  Available
# 3  Offline  Offline  Available  ...   Down  Offline  Offline  Available
# 4  Offline  Offline  Available  ...   Down  Offline  Offline  Available
#
#       S13-T2 S97-T2 S25-T1 S25-T2 S98-T2 S99-T2
# ...

# %%
#data['timestamp'] = pd.to_datetime(data['timestamp'])
#data['timestamp']=data['timestamp'].astype('datetime64[ns]')
#data.dtypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31232 entries, 0 to 31231
# Columns: 274 entries, timestamp to S99-T2
# dtypes: datetime64[ns, UTC](1), object(273)
# memory usage: 65.3+ MB

# %%
data1 = data.dropna(axis=0)
data1.head()
# Out:
#                      timestamp S7-T1      S2-T1     S19-T1     S56-T3 S85-T3  \
# 7142 2020-02-07 22:30:00+00:00  Down  Available  Available  Available   Down
# 7143 2020-02-07 22:45:00+00:00  Down  Available  Available  Available   Down
# 7144 2020-02-07 23:00:00+00:00  Down  Available  Available  Available   Down
# 7145 2020-02-07 23:15:00+00:00  Down  Available  Available  Available   Down
# 7146 2020-02-07 23:30:00+00:00  Down  Available  Available  Available   Down
#
#          S16-T3   S16-T1   S94-T3     S28-T1  ... S47-T2     S65-T2   S32-T2  \
# 7142  Available  Passive  Offline  Available  ...   Down  Available  Offline
# 7143  Available  Passive  Offline  Available  ...   Down  Available  Offline
# 7144  Available  Passive  Offline  Available  ...   Down  Available  Offline
# 7145  Available  Passive  Offline  Available  ...   Down  Available  Offline
# 7146  Available  Passive  Offline  Available  ...   Down  Available  Offline
#
# ...

# %%
df = data1 ['timestamp']
df2 = data1.drop('timestamp', axis=1)

# %%
df2.head()
# Out:
#      S7-T1      S2-T1     S19-T1     S56-T3 S85-T3     S16-T3   S16-T1  \
# 7142  Down  Available  Available  Available   Down  Available  Passive
# 7143  Down  Available  Available  Available   Down  Available  Passive
# 7144  Down  Available  Available  Available   Down  Available  Passive
# 7145  Down  Available  Available  Available   Down  Available  Passive
# 7146  Down  Available  Available  Available   Down  Available  Passive
#
#        S94-T3     S28-T1 S62-T3  ... S47-T2     S65-T2   S32-T2   S21-T2  \
# 7142  Offline  Available   Down  ...   Down  Available  Offline  Offline
# 7143  Offline  Available   Down  ...   Down  Available  Offline  Offline
# 7144  Offline  Available   Down  ...   Down  Available  Offline  Offline
# 7145  Offline  Available   Down  ...   Down  Available  Offline  Offline
# 7146  Offline  Available   Down  ...   Down  Available  Offline  Offline
#
#        S13-T2   S97-T2   S25-T1   S25-T2     S98-T2 S99-T2
# ...

# %%
data['month'] =data['timestamp'].datetime.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-76ab1ad6bacb> in <module>
# ----> 1 data['month'] =data['timestamp'].datetime.month
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
X_train, y_train =  df[:19000],df2[:19000]
X_valid,y_valid = df[19000:], df2[19000:]

# %%
dumY_train=pd.get_dummies(y_train)
dumY_valid=pd.get_dummies(y_valid)
dumY_train.head()

# %%
#data1 = df_train.fillna(method='bfill', inplace=True)
#data1 = df_train.fillna(method='bfill')
#data1  = df_train.fillna('Offline')
#data1.head()
#df2 = df_train.drop(S99-T2,200:274)
#df2 = df_train.drop(df_train.columns[[200:274]], axis=1)
#df2 = df_train.drop(df_train.iloc[:,200:274],1)
#df2.head()

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, dumY_train)
y_pred = model.predict(X_train)
print(metrics.accuracy_score(dumY_train, y_pred))
